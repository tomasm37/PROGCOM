# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasm37/PROGCOM/blob/main/Silent_teacher_Tomas_Marin_Jhonnatan_Basto_22_10_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Preguntas de abstracción
preguntas_abstraccion = [
    {
        "pregunta": "1. ¿Qué es la abstracción en programación?",
        "opciones": [
            "A) Un proceso de eliminar errores.",
            "B) Un enfoque para ocultar detalles y mostrar solo la información relevante.",  # Correcta
            "C) La creación de múltiples copias de un programa.",
            "D) Un método para optimizar el rendimiento del código."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "2. ¿Cómo se aplica la abstracción en la programación orientada a objetos?",
        "opciones": [
            "A) A través de la definición de clases abstractas y métodos.",  # Correcta
            "B) Mediante la creación de múltiples instancias de una clase.",
            "C) Usando variables globales en lugar de locales.",
            "D) Al implementar algoritmos de búsqueda."
        ],
        "respuesta": "A"
    },
    {
        "pregunta": "3. ¿Cuál es la diferencia entre abstracción y generalización?",
        "opciones": [
            "A) No hay diferencia, son términos sinónimos.",
            "B) La generalización es más complicada que la abstracción.",
            "C) La abstracción se centra en simplificar, mientras que la generalización agrupa conceptos similares.",  # Correcta
            "D) La abstracción se utiliza en programación estructurada, la generalización en programación orientada a objetos."
        ],
        "respuesta": "C"
    },
    {
        "pregunta": "4. ¿Puedes dar un ejemplo de una clase que utilice la abstracción?",
        "opciones": [
            "A) Una clase que se usa solo para hacer pruebas.",
            "B) Una clase que implementa todas sus funciones directamente.",
            "C) Una clase abstracta que define métodos sin implementar.",  # Correcta
            "D) Una clase que solo contiene variables."
        ],
        "respuesta": "C"
    },
    {
        "pregunta": "5. ¿Cómo ayuda la abstracción a simplificar el diseño de software?",
        "opciones": [
            "A) Al eliminar la necesidad de pruebas.",
            "B) Al permitir que los desarrolladores se centren en las interacciones en lugar de los detalles.",  # Correcta
            "C) Al añadir más detalles técnicos.",
            "D) Al reducir la cantidad de código escrito."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "6. ¿Qué son las interfaces y cómo se relacionan con la abstracción?",
        "opciones": [
            "A) Son funciones que solo se utilizan internamente.",
            "B) Son clases que no pueden ser instanciadas y permiten la implementación de métodos específicos.",  # Correcta
            "C) Son métodos que no pueden ser sobreescritos.",
            "D) Son estructuras de datos que almacenan información."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "7. ¿Cuáles son las ventajas de utilizar la abstracción en un proyecto?",
        "opciones": [
            "A) Aumenta la complejidad del código.",
            "B) Facilita la reutilización de código y mejora la mantenibilidad.",  # Correcta
            "C) Elimina la necesidad de comentarios.",
            "D) Reduce el número de funciones en el programa."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "8. ¿Cómo se relaciona la abstracción con la reducción de la complejidad?",
        "opciones": [
            "A) La complejidad se incrementa con la abstracción.",
            "B) La complejidad se maneja mejor con más clases.",
            "C) La abstracción ayuda a ocultar detalles innecesarios, lo que reduce la complejidad.",  # Correcta
            "D) La abstracción solo aplica a pequeños programas."
        ],
        "respuesta": "C"
    },
    {
        "pregunta": "9. ¿Qué rol juegan las clases abstractas en la abstracción?",
        "opciones": [
            "A) Son clases que deben ser instanciadas.",
            "B) Definen una interfaz sin proporcionar implementación.",  # Correcta
            "C) Permiten la creación de objetos concretos.",
            "D) Solo se utilizan en la programación funcional."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "10. ¿Por qué es importante ocultar detalles innecesarios en un sistema?",
        "opciones": [
            "A) Para aumentar la cantidad de código.",
            "B) Para permitir que los desarrolladores se concentren en lo esencial.",  # Correcta
            "C) Para hacer el código más confuso.",
            "D) Para evitar que se realicen pruebas."
        ],
        "respuesta": "B"
    }
]

# Preguntas de encapsulamiento
preguntas_encapsulamiento = [
    {
        "pregunta": "1. ¿Qué es el encapsulamiento en programación?",
        "opciones": [
            "A) Un proceso de dividir el código en múltiples archivos.",
            "B) La práctica de ocultar los datos internos de un objeto.",  # Correcta
            "C) La creación de interfaces gráficas.",
            "D) Un método para optimizar consultas a bases de datos."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "2. ¿Cuáles son los beneficios del encapsulamiento en el desarrollo de software?",
        "opciones": [
            "A) Mejora la seguridad y la integridad de los datos.",  # Correcta
            "B) Permite que todas las variables sean públicas.",
            "C) Aumenta la interdependencia entre clases.",
            "D) Hace que el código sea más difícil de leer."
        ],
        "respuesta": "A"
    },
    {
        "pregunta": "3. ¿Cómo se implementa el encapsulamiento en una clase?",
        "opciones": [
            "A) Ignorando el uso de métodos.",
            "B) Utilizando modificadores de acceso para restringir el acceso a los datos.",  # Correcta
            "C) Declarando todas las variables como públicas.",
            "D) Creando métodos que no realizan ninguna acción."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "4. ¿Qué significa 'ocultar la implementación' y cómo se relaciona con el encapsulamiento?",
        "opciones": [
            "A) Proteger los detalles de cómo funciona un objeto, exponiendo solo lo necesario.",  # Correcta
            "B) Hacer que el código sea más complicado.",
            "C) Reducir el tamaño del código.",
            "D) Aumentar la complejidad del diseño."
        ],
        "respuesta": "A"
    },
    {
        "pregunta": "5. ¿Puedes dar un ejemplo práctico de encapsulamiento en una clase?",
        "opciones": [
            "A) Una clase que permite acceso directo a sus variables.",
            "B) Una clase que utiliza métodos públicos para acceder a variables privadas.",  # Correcta
            "C) Una clase sin métodos.",
            "D) Una clase que no tiene variables."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "6. ¿Cómo ayuda el encapsulamiento a mantener la integridad de los datos?",
        "opciones": [
            "A) Restringiendo el acceso a los datos y validando la entrada.",  # Correcta
            "B) Aumentando la visibilidad de las variables.",
            "C) Eliminando la necesidad de pruebas.",
            "D) Permitiendo cambios sin control."
        ],
        "respuesta": "A"
    },
    {
        "pregunta": "7. ¿Qué son los modificadores de acceso y cómo afectan el encapsulamiento?",
        "opciones": [
            "A) Comandos para ejecutar programas.",
            "B) Estructuras que almacenan datos.",
            "C) Palabras clave que determinan la visibilidad de variables y métodos.",  # Correcta
            "D) Funciones que no devuelven valores."
        ],
        "respuesta": "C"
    },
    {
        "pregunta": "8. ¿Por qué el encapsulamiento es fundamental para el mantenimiento de un sistema?",
        "opciones": [
            "A) Hace que el código sea más confuso.",
            "B) Permite cambios internos sin afectar a otros componentes.",  # Correcta
            "C) Aumenta la dependencia entre módulos.",
            "D) Elimina la necesidad de comentarios."
        ],
        "respuesta": "B"
    },
    {
        "pregunta": "9. ¿Cómo se relaciona el encapsulamiento con la idea de interfaz pública y privada?",
        "opciones": [
            "A) El encapsulamiento separa la interfaz pública de la implementación privada.",  # Correcta
            "B) La interfaz pública es innecesaria.",
            "C) No hay relación entre ambos conceptos.",
            "D) Ambos son iguales en programación."
        ],
        "respuesta": "A"
    },
    {
        "pregunta": "10. ¿Cuáles son las consecuencias de no aplicar el encapsulamiento en un programa?",
        "opciones": [
            "A) Mejora la legibilidad del código.",
            "B) Aumenta el riesgo de errores y hace más difícil el mantenimiento.",  # Correcta
            "C) Reduce la cantidad de código necesario.",
            "D) Facilita la colaboración entre equipos."
        ],
        "respuesta": "B"
    }
]


def jugar():
    print("Bienvenido al juego Silent Teacher de preguntas sobre Abstracción y Encapsulamiento.")

    # Variables para seguimiento de respuestas correctas
    respuestas_correctas_abstraccion = 0
    preguntas_intentadas_abstraccion = []

    # Juego de abstracción
    while respuestas_correctas_abstraccion < 5:
        pregunta = random.choice(preguntas_abstraccion)

        # Verificar si ya se intentó la pregunta
        if pregunta not in preguntas_intentadas_abstraccion:
            print(pregunta["pregunta"])
            for opcion in pregunta["opciones"]:
                print(opcion)

            respuesta_usuario = input("Elige la opción correcta (A, B, C, D): ").strip().upper()

            if respuesta_usuario == pregunta["respuesta"]:
                print("¡Correcto!\n")
                preguntas_intentadas_abstraccion.append(pregunta)
                respuestas_correctas_abstraccion += 1
            else:
                print("Incorrecto. ¡Intenta de nuevo!\n")
                # No añadir a las intentadas, así se puede repetir

    print("¡Has respondido correctamente las 5 preguntas de Abstracción!\n")

    # Variables para seguimiento de respuestas correctas de encapsulamiento
    respuestas_correctas_encapsulamiento = 0
    preguntas_intentadas_encapsulamiento = []

    # Juego de encapsulamiento
    while respuestas_correctas_encapsulamiento < 5:
        pregunta = random.choice(preguntas_encapsulamiento)

        # Verificar si ya se intentó la pregunta
        if pregunta not in preguntas_intentadas_encapsulamiento:
            print(pregunta["pregunta"])
            for opcion in pregunta["opciones"]:
                print(opcion)

            respuesta_usuario = input("Elige la opción correcta (A, B, C, D): ").strip().upper()

            if respuesta_usuario == pregunta["respuesta"]:
                print("¡Correcto!\n")
                preguntas_intentadas_encapsulamiento.append(pregunta)
                respuestas_correctas_encapsulamiento += 1
            else:
                print("Incorrecto. ¡Intenta de nuevo!\n")
                # No añadir a las intentadas, así se puede repetir

    print("¡Felicidades! Has respondido correctamente las 5 preguntas de Abstracción y 5 de Encapsulamiento.")
    print("¡Has completado el juego!")

# Iniciar el juego
jugar()
# Out:
# Bienvenido al juego Silent Teacher de preguntas sobre Abstracción y Encapsulamiento.
# 1. ¿Qué es la abstracción en programación?
# A) Un proceso de eliminar errores.
# B) Un enfoque para ocultar detalles y mostrar solo la información relevante.
# C) La creación de múltiples copias de un programa.
# D) Un método para optimizar el rendimiento del código.
# Elige la opción correcta (A, B, C, D): b
# ¡Correcto!
#
# 10. ¿Por qué es importante ocultar detalles innecesarios en un sistema?
# A) Para hacer el código más confuso.
# B) Para permitir que los desarrolladores se concentren en lo esencial.
# C) Para aumentar la cantidad de código.
# D) Para evitar que se realicen pruebas.
# Elige la opción correcta (A, B, C, D): b
# ¡Correcto!
#
# 2. ¿Cómo se aplica la abstracción en la programación orientada a objetos?
# A) Mediante la creación de múltiples instancias de una clase.
# B) A través de la definición de clases abstractas y métodos.
# C) Usando variables globales en lugar de locales.
# ...
